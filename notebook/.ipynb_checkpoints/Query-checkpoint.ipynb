# %% [markdown]
# # ANALYZE INTERNATIONAL DEBT STATISTICS

# %% [markdown]
# ## Team Name : ANALYZER
#
# ## Team Member :
#
# - ABDUL JAWEED
# - PRATEEK CHAURASIA

# %% [markdown]
# ## Problem Statement:
#
# It's not that we humans only take debts to manage our necessities. A country
# may also take debt to manage its economy. For example, infrastructure spending is one costly ingredient required for a country's citizens to lead comfortable lives. [The World Bank](https://www.worldbank.org/en/home) is the organization that provides debt to countries.
#
# In this project, you are going to analyze international debt data collected by The World Bank. The dataset contains information about the amount of debt (in USD) owed by developing countries across several categories. You are going to find the answers to questions like:
# - What is the total amount of debt that is owed by the countries listed in the dataset?
# - Which country owns the maximum amount of debt and what does that amount
# look like?
# - What is the average amount of debt owed by countries across different debt
# indicators?
#
# The data used in this project is provided by [The World Bank](https://www.worldbank.org/en/home). It contains both national and regional debt statistics for several countries across the globe as recorded from 1970 to 2027.
#
#
# ## Project Tasks
#
# - 1. The World Bank's international debt data
# - 2. Finding the number of distinct countries
# - 3. Finding out the distinct debt indicators
# - 4. Totaling the amount of debt owed by the countries
# - 5. Country with the highest debt
# - 6. Average amount of debt across indicators
# - 7. The highest amount of principal repayments
# - 8. The most common debt indicator
# - 9. Other viable debt issues and conclusion
#
#
# ## Dataset:
#
# Dataset is available in the given link. You can download as per your convenient.
#
# [International Debt Statistics (IDS) | Data Catalog (worldbank.org)](https://datacatalog.worldbank.org/search/dataset/0038015)
#
# ## Approaches:
#
# SQL, Power BI or you can use any tools and techniques as per your
# convenience. We would appreciate your valid imagination in finding solutions.

# %% [markdown]
# ### Importing Libraries

# %%
# import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("clean.csv")

# %% [markdown]
# ## Q1) The World Bank's international debt data

# %%
df.head(15)
# Out:
#    country_name country_code  \
# 0   Afghanistan          AFG
# 1   Afghanistan          AFG
# 2   Afghanistan          AFG
# 3   Afghanistan          AFG
# 4   Afghanistan          AFG
# 5   Afghanistan          AFG
# 6   Afghanistan          AFG
# 7   Afghanistan          AFG
# 8   Afghanistan          AFG
# 9   Afghanistan          AFG
# 10  Afghanistan          AFG
# 11  Afghanistan          AFG
# 12  Afghanistan          AFG
# 13  Afghanistan          AFG
# 14  Afghanistan          AFG
#
#                                        indicator_name     indicator_code  debt
# 0   Average grace period on new external debt comm...        DT.GPA.DPPG   104
# 1   Average grace period on new external debt comm...        DT.GPA.OFFT   104
# 2   Average grace period on new external debt comm...        DT.GPA.PRVT     0
# 3   Average grant element on new external debt com...        DT.GRE.DPPG   392
# 4   Average grant element on new external debt com...        DT.GRE.OFFT   392
# 5   Average grant element on new external debt com...        DT.GRE.PRVT     0
# 6   Average interest on new external debt commitme...        DT.INR.DPPG     7
# 7   Average interest on new external debt commitme...        DT.INR.OFFT     7
# 8   Average interest on new external debt commitme...        DT.INR.PRVT     0
# 9   Average maturity on new external debt commitme...        DT.MAT.DPPG   247
# 10  Average maturity on new external debt commitme...        DT.MAT.OFFT   247
# 11  Average maturity on new external debt commitme...        DT.MAT.PRVT     0
# 12                   CB, bilateral (AMT, current US$)  DT.AMT.BLAT.CB.CD     0
# 13                   CB, bilateral (DIS, current US$)  DT.DIS.BLAT.CB.CD     0
# 14                   CB, bilateral (DOD, current US$)  DT.DOD.BLAT.CB.CD     0

# %% [markdown]
# ## Q2) Finding the number of distinct countries

# %%
df.country_name.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Azerbaijan', 'Bangladesh', 'Belarus', 'Belize',
#        'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde',
#        'Cambodia', 'Cameroon', 'Central African Republic', 'Chad',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
#        'Eritrea', 'Eswatini', 'Ethiopia', 'Fiji', 'Gabon', 'Gambia, The',
#        'Georgia', 'Ghana', 'Grenada', 'Guatemala', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'IDA only',
#        'India', 'Indonesia', 'Iran, Islamic Rep.', 'Jamaica', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Kosovo', 'Kyrgyz Republic', 'Lao PDR',
#        'Lebanon', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi',
#        'Maldives', 'Mali', 'Mauritania', 'Mauritius', 'Mexico',
#        'Middle East & North Africa (excluding high income)', 'Moldova',
#        'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar',
#        'Nepal', 'Nicaragua', 'Niger', 'Nigeria', 'North Macedonia',
#        'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines', 'Romania', 'Russian Federation', 'Rwanda', 'Samoa',
#        'Sao Tome and Principe', 'Senegal', 'Serbia', 'Sierra Leone',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Asia',
#        'Sri Lanka', 'St. Lucia', 'St. Vincent and the Grenadines',
#        'Sudan', 'Syrian Arab Republic', 'Tajikistan', 'Tanzania',
#        'Thailand', 'Timor-Leste', 'Togo', 'Tonga', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Uganda', 'Ukraine', 'Uzbekistan', 'Vanuatu',
#        'Venezuela, RB', 'Vietnam', 'Yemen, Rep.', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %% [markdown]
# ## Q3) Finding out the distinct debt indicators

# %%
df.indicator_code.unique()
# Out:
# array(['DT.GPA.DPPG', 'DT.GPA.OFFT', 'DT.GPA.PRVT', 'DT.GRE.DPPG',
#        'DT.GRE.OFFT', 'DT.GRE.PRVT', 'DT.INR.DPPG', 'DT.INR.OFFT',
#        'DT.INR.PRVT', 'DT.MAT.DPPG', 'DT.MAT.OFFT', 'DT.MAT.PRVT',
#        'DT.AMT.BLAT.CB.CD', 'DT.DIS.BLAT.CB.CD', 'DT.DOD.BLAT.CB.CD',
#        'DT.INT.BLAT.CB.CD', 'DT.NFL.BLAT.CB.CD', 'DT.NTR.BLAT.CB.CD',
#        'DT.TDS.BLAT.CB.CD', 'DT.AMT.BLTC.CB.CD', 'DT.DIS.BLTC.CB.CD',
#        'DT.DOD.BLTC.CB.CD', 'DT.INT.BLTC.CB.CD', 'DT.NFL.BLTC.CB.CD',
#        'DT.NTR.BLTC.CB.CD', 'DT.TDS.BLTC.CB.CD', 'DT.AMT.PBND.CB.CD',
#        'DT.DIS.PBND.CB.CD', 'DT.DOD.PBND.CB.CD', 'DT.INT.PBND.CB.CD',
#        'DT.NFL.PBND.CB.CD', 'DT.NTR.PBND.CB.CD', 'DT.TDS.PBND.CB.CD',
#        'DT.AMT.PCBK.CB.CD', 'DT.DIS.PCBK.CB.CD', 'DT.DOD.PCBK.CB.CD',
#        'DT.INT.PCBK.CB.CD', 'DT.NFL.PCBK.CB.CD', 'DT.NTR.PCBK.CB.CD',
#        'DT.TDS.PCBK.CB.CD', 'DT.AMT.MLAT.CB.CD', 'DT.DIS.MLAT.CB.CD',
#        'DT.DOD.MLAT.CB.CD', 'DT.INT.MLAT.CB.CD', 'DT.NFL.MLAT.CB.CD',
#        'DT.NTR.MLAT.CB.CD', 'DT.TDS.MLAT.CB.CD', 'DT.AMT.MLTC.CB.CD',
#        'DT.DIS.MLTC.CB.CD', 'DT.DOD.MLTC.CB.CD', 'DT.INT.MLTC.CB.CD',
#        'DT.NFL.MLTC.CB.CD', 'DT.NTR.MLTC.CB.CD', 'DT.TDS.MLTC.CB.CD',
#        'DT.AMT.OFFT.CB.CD', 'DT.DIS.OFFT.CB.CD', 'DT.DOD.OFFT.CB.CD',
#        'DT.INT.OFFT.CB.CD', 'DT.NFL.OFFT.CB.CD', 'DT.NTR.OFFT.CB.CD',
#        'DT.TDS.OFFT.CB.CD', 'DT.AMT.PROP.CB.CD', 'DT.DIS.PROP.CB.CD',
#        'DT.DOD.PROP.CB.CD', 'DT.INT.PROP.CB.CD', 'DT.NFL.PROP.CB.CD',
#        'DT.NTR.PROP.CB.CD', 'DT.TDS.PROP.CB.CD', 'DT.AMT.PRVT.CB.CD',
#        'DT.DIS.PRVT.CB.CD', 'DT.DOD.PRVT.CB.CD', 'DT.INT.PRVT.CB.CD',
#        'DT.NFL.PRVT.CB.CD', 'DT.NTR.PRVT.CB.CD', 'DT.TDS.PRVT.CB.CD',
#        'DT.COM.BLAT.CD', 'DT.COM.MIBR.CD', 'DT.COM.MIDA.CD',
#        'DT.COM.MLAT.CD', 'DT.COM.OFFT.CD', 'DT.COM.PRVT.CD',
#        'DT.COM.DPPG.CD', 'DT.DOD.ALLC.ZS', 'DT.CUR.OTHC.ZS',
#        'DT.CUR.DMAK.ZS', 'DT.CUR.EURO.ZS', 'DT.CUR.FFRC.ZS',
#        'DT.CUR.JYEN.ZS', 'DT.CUR.MULC.ZS', 'DT.CUR.UKPS.ZS',
#        'DT.CUR.SDRW.ZS', 'DT.CUR.SWFR.ZS', 'DT.CUR.USDL.ZS',
#        'BN.CAB.XOKA.CD', 'DT.DSB.DPPG.CD', 'DT.DOD.MDRI.CD',
#        'DT.DFR.DPPG.CD', 'DT.TDS.DECB.CD', 'DT.TDS.DEGG.CD',
#        'DT.TDS.DLXF.CD', 'DT.TDS.DOPS.CD', 'DT.TDS.PRPG.CD',
#        'DT.TDS.DPNG.CD', 'DT.TDS.DPPG.CD', 'DT.TDS.DEPS.CD',
#        'DT.TDS.DECT.CD', 'DT.DSF.DPPG.CD', 'DT.DXR.DPPG.CD',
#        'DT.DIS.DECB.CD', 'DT.DIS.DEGG.CD', 'DT.DIS.DLXF.CD',
#        'DT.DIS.DLTF.CD', 'DT.DIS.DOPS.CD', 'DT.DIS.PRPG.CD',
#        'DT.DIS.DPNG.CD', 'DT.DIS.DPPG.CD', 'DT.DIS.DEPS.CD',
#        'DT.NFL.NEBR.CD', 'BX.GSR.TOTL.CD', 'DT.DOD.DECT.EX.ZS',
#        'DT.DOD.DECT.GN.ZS', 'DT.DOD.DECB.CD', 'DT.DOD.ALLC.CD',
#        'DT.DOD.DEGG.CD', 'DT.DOD.DLXF.CD', 'DT.DOD.PRVS.CD',
#        'DT.DOD.PUBS.CD', 'DT.DOD.DOPS.CD', 'DT.DOD.PRPG.CD',
#        'DT.DOD.DPNG.CD', 'DT.DOD.DPPG.CD', 'DT.DOD.DEPS.CD',
#        'DT.DOD.DSTC.CD', 'DT.DOD.DECT.CD', 'DT.DOD.VTOT.CD',
#        'BX.KLT.DINV.CD.DT', 'DT.AMT.BLAT.GG.CD', 'DT.DIS.BLAT.GG.CD',
#        'DT.DOD.BLAT.GG.CD', 'DT.INT.BLAT.GG.CD', 'DT.NFL.BLAT.GG.CD',
#        'DT.NTR.BLAT.GG.CD', 'DT.TDS.BLAT.GG.CD', 'DT.AMT.BLTC.GG.CD',
#        'DT.DIS.BLTC.GG.CD', 'DT.DOD.BLTC.GG.CD', 'DT.INT.BLTC.GG.CD',
#        'DT.NFL.BLTC.GG.CD', 'DT.NTR.BLTC.GG.CD', 'DT.TDS.BLTC.GG.CD',
#        'DT.AMT.PBND.GG.CD', 'DT.DIS.PBND.GG.CD', 'DT.DOD.PBND.GG.CD',
#        'DT.INT.PBND.GG.CD', 'DT.NFL.PBND.GG.CD', 'DT.NTR.PBND.GG.CD',
#        'DT.TDS.PBND.GG.CD', 'DT.AMT.PCBK.GG.CD', 'DT.DIS.PCBK.GG.CD',
#        'DT.DOD.PCBK.GG.CD', 'DT.INT.PCBK.GG.CD', 'DT.NFL.PCBK.GG.CD',
#        'DT.NTR.PCBK.GG.CD', 'DT.TDS.PCBK.GG.CD', 'DT.AMT.MLAT.GG.CD',
#        'DT.DIS.MLAT.GG.CD', 'DT.DOD.MLAT.GG.CD', 'DT.INT.MLAT.GG.CD',
#        'DT.NFL.MLAT.GG.CD', 'DT.NTR.MLAT.GG.CD', 'DT.TDS.MLAT.GG.CD',
#        'DT.AMT.MLTC.GG.CD', 'DT.DIS.MLTC.GG.CD', 'DT.DOD.MLTC.GG.CD',
#        'DT.INT.MLTC.GG.CD', 'DT.NFL.MLTC.GG.CD', 'DT.NTR.MLTC.GG.CD',
#        'DT.TDS.MLTC.GG.CD', 'DT.AMT.OFFT.GG.CD', 'DT.DIS.OFFT.GG.CD',
#        'DT.DOD.OFFT.GG.CD', 'DT.INT.OFFT.GG.CD', 'DT.NFL.OFFT.GG.CD',
#        'DT.NTR.OFFT.GG.CD', 'DT.TDS.OFFT.GG.CD', 'DT.AMT.PROP.GG.CD',
#        'DT.DIS.PROP.GG.CD', 'DT.DOD.PROP.GG.CD', 'DT.INT.PROP.GG.CD',
#        'DT.NFL.PROP.GG.CD', 'DT.NTR.PROP.GG.CD', 'DT.TDS.PROP.GG.CD',
#        'DT.AMT.PRVT.GG.CD', 'DT.DIS.PRVT.GG.CD', 'DT.DOD.PRVT.GG.CD',
#        'DT.INT.PRVT.GG.CD', 'DT.NFL.PRVT.GG.CD', 'DT.NTR.PRVT.GG.CD',
#        'DT.TDS.PRVT.GG.CD', 'NY.GNP.MKTP.CD', 'BX.GRT.EXTA.CD.DT',
#        'DT.DIS.IDAG.CD', 'DT.NFL.NIFC.CD', 'DT.INT.DIMF.CD',
#        'DT.DIS.DIMF.CD', 'DT.AMT.DIMF.CD', 'DT.TDS.DIMF.CD',
#        'BM.GSR.TOTL.CD', 'DT.IXA.DLXF.CD', 'DT.IXA.OFFT.CD',
#        'DT.IXA.PRVT.CD', 'DT.IXF.DPPG.CD', 'DT.INT.DECT.EX.ZS',
#        'DT.INT.DECT.GN.ZS', 'DT.INT.DECB.CD', 'DT.INT.DEGG.CD',
#        'DT.INT.DLXF.CD', 'DT.INT.DOPS.CD', 'DT.INT.PRPG.CD',
#        'DT.INT.DPNG.CD', 'DT.INT.DPPG.CD', 'DT.INT.DEPS.CD',
#        'DT.INT.DSTC.CD', 'DT.INT.DECT.CD', 'DT.IXR.DPPG.CD',
#        'DT.IXR.OFFT.CD', 'DT.IXR.PRVT.CD', 'DT.DOD.MLAT.ZS',
#        'DT.TDS.MLAT.CD', 'DT.IXA.DPPG.CD.CG', 'DT.NFL.BLAT.CD',
#        'DT.NFL.MIBR.CD', 'DT.NFL.MIDA.CD', 'DT.NFL.IMFC.CD',
#        'DT.NFL.IMFN.CD', 'DT.NFL.MLAT.CD', 'DT.NFL.MOTH.CD',
#        'DT.NFL.RDBC.CD', 'DT.NFL.RDBN.CD', 'DT.NFL.DECB.CD',
#        'DT.NFL.DEGG.CD', 'DT.NFL.DLXF.CD', 'DT.NFL.DOPS.CD',
#        'DT.NFL.PRPG.CD', 'DT.NFL.DPNG.CD', 'DT.NFL.DPPG.CD',
#        'DT.NFL.DEPS.CD', 'DT.NFL.DSTC.CD', 'DT.NFL.DECT.CD',
#        'DT.NTR.DECB.CD', 'DT.NTR.DEGG.CD', 'DT.NTR.DLXF.CD',
#        'DT.NTR.DOPS.CD', 'DT.NTR.PRPG.CD', 'DT.NTR.DPNG.CD',
#        'DT.NTR.DPPG.CD', 'DT.NTR.DEPS.CD', 'DT.NTR.DECT.CD',
#        'DT.AMT.BLAT.OPS.CD', 'DT.DIS.BLAT.OPS.CD', 'DT.DOD.BLAT.OPS.CD',
#        'DT.INT.BLAT.OPS.CD', 'DT.NFL.BLAT.OPS.CD', 'DT.NTR.BLAT.OPS.CD',
#        'DT.TDS.BLAT.OPS.CD', 'DT.AMT.BLTC.OPS.CD', 'DT.DIS.BLTC.OPS.CD',
#        'DT.DOD.BLTC.OPS.CD', 'DT.INT.BLTC.OPS.CD', 'DT.NFL.BLTC.OPS.CD',
#        'DT.NTR.BLTC.OPS.CD', 'DT.TDS.BLTC.OPS.CD', 'DT.AMT.PBND.OPS.CD',
#        'DT.DIS.PBND.OPS.CD', 'DT.DOD.PBND.OPS.CD', 'DT.INT.PBND.OPS.CD',
#        'DT.NFL.PBND.OPS.CD', 'DT.NTR.PBND.OPS.CD', 'DT.TDS.PBND.OPS.CD',
#        'DT.AMT.PCBK.OPS.CD', 'DT.DIS.PCBK.OPS.CD', 'DT.DOD.PCBK.OPS.CD',
#        'DT.INT.PCBK.OPS.CD', 'DT.NFL.PCBK.OPS.CD', 'DT.NTR.PCBK.OPS.CD',
#        'DT.TDS.PCBK.OPS.CD', 'DT.AMT.MLAT.OPS.CD', 'DT.DIS.MLAT.OPS.CD',
#        'DT.DOD.MLAT.OPS.CD', 'DT.INT.MLAT.OPS.CD', 'DT.NFL.MLAT.OPS.CD',
#        'DT.NTR.MLAT.OPS.CD', 'DT.TDS.MLAT.OPS.CD', 'DT.AMT.MLTC.OPS.CD',
#        'DT.DIS.MLTC.OPS.CD', 'DT.DOD.MLTC.OPS.CD', 'DT.INT.MLTC.OPS.CD',
#        'DT.NFL.MLTC.OPS.CD', 'DT.NTR.MLTC.OPS.CD', 'DT.TDS.MLTC.OPS.CD',
#        'DT.AMT.OFFT.OPS.CD', 'DT.DIS.OFFT.OPS.CD', 'DT.DOD.OFFT.OPS.CD',
#        'DT.INT.OFFT.OPS.CD', 'DT.NFL.OFFT.OPS.CD', 'DT.NTR.OFFT.OPS.CD',
#        'DT.TDS.OFFT.OPS.CD', 'DT.AMT.PROP.OPS.CD', 'DT.DIS.PROP.OPS.CD',
#        'DT.DOD.PROP.OPS.CD', 'DT.INT.PROP.OPS.CD', 'DT.NFL.PROP.OPS.CD',
#        'DT.NTR.PROP.OPS.CD', 'DT.TDS.PROP.OPS.CD', 'DT.AMT.PRVT.OPS.CD',
#        'DT.DIS.PRVT.OPS.CD', 'DT.DOD.PRVT.OPS.CD', 'DT.INT.PRVT.OPS.CD',
#        'DT.NFL.PRVT.OPS.CD', 'DT.NTR.PRVT.OPS.CD', 'DT.TDS.PRVT.OPS.CD',
#        'BX.TRF.PWKR.CD.DT', 'DT.AMT.PNGB.CD', 'DT.DIS.PNGB.CD',
#        'DT.DOD.PNGB.CD', 'DT.INT.PNGB.CD', 'DT.NFL.PNGB.CD',
#        'DT.NTR.PNGB.CD', 'DT.TDS.PNGB.CD', 'DT.AMT.PNGC.CD',
#        'DT.DIS.PNGC.CD', 'DT.DOD.PNGC.CD', 'DT.INT.PNGC.CD',
#        'DT.NFL.PNGC.CD', 'DT.NTR.PNGC.CD', 'DT.TDS.PNGC.CD',
#        'BX.PEF.TOTL.CD.DT', 'DT.AMT.BLAT.CD', 'DT.DIS.BLAT.CD',
#        'DT.DOD.BLAT.CD', 'DT.INT.BLAT.CD', 'DT.NTR.BLAT.CD',
#        'DT.TDS.BLAT.CD', 'DT.AMT.BLTC.CD', 'DT.DIS.BLTC.CD',
#        'DT.DOD.BLTC.CD', 'DT.INT.BLTC.CD', 'DT.NFL.BLTC.CD',
#        'DT.NTR.BLTC.CD', 'DT.TDS.BLTC.CD', 'DT.AMT.PBND.CD',
#        'DT.DIS.PBND.CD', 'DT.DOD.PBND.CD', 'DT.INT.PBND.CD',
#        'DT.NFL.PBND.CD', 'DT.NTR.PBND.CD', 'DT.TDS.PBND.CD',
#        'DT.AMT.PCBK.CD', 'DT.DIS.PCBK.CD', 'DT.DOD.PCBK.CD',
#        'DT.INT.PCBK.CD', 'DT.NFL.PCBK.CD', 'DT.NTR.PCBK.CD',
#        'DT.TDS.PCBK.CD', 'DT.AMT.MIBR.CD', 'DT.DIS.MIBR.CD',
#        'DT.DOD.MIBR.CD', 'DT.INT.MIBR.CD', 'DT.NTR.MIBR.CD',
#        'DT.TDS.MIBR.CD', 'DT.AMT.MIDA.CD', 'DT.DIS.MIDA.CD',
#        'DT.DOD.MIDA.CD', 'DT.INT.MIDA.CD', 'DT.NTR.MIDA.CD',
#        'DT.TDS.MIDA.CD', 'DT.AMT.MLAT.CD', 'DT.DIS.MLAT.CD',
#        'DT.DOD.MLAT.CD', 'DT.INT.MLAT.CD', 'DT.NTR.MLAT.CD',
#        'DT.AMT.MLTC.CD', 'DT.DIS.MLTC.CD', 'DT.DOD.MLTC.CD',
#        'DT.INT.MLTC.CD', 'DT.NFL.MLTC.CD', 'DT.NTR.MLTC.CD',
#        'DT.TDS.MLTC.CD', 'DT.AMT.OFFT.CD', 'DT.DIS.OFFT.CD',
#        'DT.DOD.OFFT.CD', 'DT.INT.OFFT.CD', 'DT.NFL.OFFT.CD',
#        'DT.NTR.OFFT.CD', 'DT.TDS.OFFT.CD', 'DT.AMT.PROP.CD',
#        'DT.DIS.PROP.CD', 'DT.DOD.PROP.CD', 'DT.INT.PROP.CD',
#        'DT.NFL.PROP.CD', 'DT.NTR.PROP.CD', 'DT.TDS.PROP.CD',
#        'DT.AMT.PRVT.CD', 'DT.DIS.PRVT.CD', 'DT.DOD.PRVT.CD',
#        'DT.INT.PRVT.CD', 'DT.NFL.PRVT.CD', 'DT.NTR.PRVT.CD',
#        'DT.TDS.PRVT.CD', 'DT.DOD.PVLX.EX.ZS', 'DT.DOD.PVLX.GN.ZS',
#        'DT.DOD.PVLX.CD', 'BX.KLT.DREM.CD.DT', 'DT.AXA.DLXF.CD',
#        'DT.AXA.OFFT.CD', 'DT.AXA.PRVT.CD', 'DT.AXF.DPPG.CD',
#        'DT.AMT.DECB.CD', 'DT.AMT.DEGG.CD', 'DT.AMT.DLXF.CD',
#        'DT.AMT.DLTF.CD', 'DT.AMT.DOPS.CD', 'DT.AMT.PRPG.CD',
#        'DT.AMT.DPNG.CD', 'DT.AMT.DPPG.CD', 'DT.AMT.DEPS.CD',
#        'DT.AXR.DPPG.CD', 'DT.AXR.OFFT.CD', 'DT.AXR.PRVT.CD',
#        'DT.AMT.BLAT.PRVG.CD', 'DT.DIS.BLAT.PRVG.CD',
#        'DT.DOD.BLAT.PRVG.CD', 'DT.INT.BLAT.PRVG.CD',
#        'DT.NFL.BLAT.PRVG.CD', 'DT.NTR.BLAT.PRVG.CD',
#        'DT.TDS.BLAT.PRVG.CD', 'DT.AMT.BLTC.PRVG.CD',
#        'DT.DIS.BLTC.PRVG.CD', 'DT.DOD.BLTC.PRVG.CD',
#        'DT.INT.BLTC.PRVG.CD', 'DT.NFL.BLTC.PRVG.CD',
#        'DT.NTR.BLTC.PRVG.CD', 'DT.TDS.BLTC.PRVG.CD',
#        'DT.AMT.PBND.PRVG.CD', 'DT.DIS.PBND.PRVG.CD',
#        'DT.DOD.PBND.PRVG.CD', 'DT.INT.PBND.PRVG.CD',
#        'DT.NFL.PBND.PRVG.CD', 'DT.NTR.PBND.PRVG.CD',
#        'DT.TDS.PBND.PRVG.CD', 'DT.AMT.PCBK.PRVG.CD',
#        'DT.DIS.PCBK.PRVG.CD', 'DT.DOD.PCBK.PRVG.CD',
#        'DT.INT.PCBK.PRVG.CD', 'DT.NFL.PCBK.PRVG.CD',
#        'DT.NTR.PCBK.PRVG.CD', 'DT.TDS.PCBK.PRVG.CD',
#        'DT.AMT.MLAT.PRVG.CD', 'DT.DIS.MLAT.PRVG.CD',
#        'DT.DOD.MLAT.PRVG.CD', 'DT.INT.MLAT.PRVG.CD',
#        'DT.NFL.MLAT.PRVG.CD', 'DT.NTR.MLAT.PRVG.CD',
#        'DT.TDS.MLAT.PRVG.CD', 'DT.AMT.MLTC.PRVG.CD',
#        'DT.DIS.MLTC.PRVG.CD', 'DT.DOD.MLTC.PRVG.CD',
#        'DT.INT.MLTC.PRVG.CD', 'DT.NFL.MLTC.PRVG.CD',
#        'DT.NTR.MLTC.PRVG.CD', 'DT.TDS.MLTC.PRVG.CD',
#        'DT.AMT.OFFT.PRVG.CD', 'DT.DIS.OFFT.PRVG.CD',
#        'DT.DOD.OFFT.PRVG.CD', 'DT.INT.OFFT.PRVG.CD',
#        'DT.NFL.OFFT.PRVG.CD', 'DT.NTR.OFFT.PRVG.CD',
#        'DT.TDS.OFFT.PRVG.CD', 'DT.AMT.PROP.PRVG.CD',
#        'DT.DIS.PROP.PRVG.CD', 'DT.DOD.PROP.PRVG.CD',
#        'DT.INT.PROP.PRVG.CD', 'DT.NFL.PROP.PRVG.CD',
#        'DT.NTR.PROP.PRVG.CD', 'DT.TDS.PROP.PRVG.CD',
#        'DT.AMT.PRVT.PRVG.CD', 'DT.DIS.PRVT.PRVG.CD',
#        'DT.DOD.PRVT.PRVG.CD', 'DT.INT.PRVT.PRVG.CD',
#        'DT.NFL.PRVT.PRVG.CD', 'DT.NTR.PRVT.PRVG.CD',
#        'DT.TDS.PRVT.PRVG.CD', 'DT.AMT.BLAT.PS.CD', 'DT.DIS.BLAT.PS.CD',
#        'DT.DOD.BLAT.PS.CD', 'DT.INT.BLAT.PS.CD', 'DT.NFL.BLAT.PS.CD',
#        'DT.NTR.BLAT.PS.CD', 'DT.TDS.BLAT.PS.CD', 'DT.AMT.BLTC.PS.CD',
#        'DT.DIS.BLTC.PS.CD', 'DT.DOD.BLTC.PS.CD', 'DT.INT.BLTC.PS.CD',
#        'DT.NFL.BLTC.PS.CD', 'DT.NTR.BLTC.PS.CD', 'DT.TDS.BLTC.PS.CD',
#        'DT.AMT.PBND.PS.CD', 'DT.DIS.PBND.PS.CD', 'DT.DOD.PBND.PS.CD',
#        'DT.INT.PBND.PS.CD', 'DT.NFL.PBND.PS.CD', 'DT.NTR.PBND.PS.CD',
#        'DT.TDS.PBND.PS.CD', 'DT.AMT.PCBK.PS.CD', 'DT.DIS.PCBK.PS.CD',
#        'DT.DOD.PCBK.PS.CD', 'DT.INT.PCBK.PS.CD', 'DT.NFL.PCBK.PS.CD',
#        'DT.NTR.PCBK.PS.CD', 'DT.TDS.PCBK.PS.CD', 'DT.AMT.MLAT.PS.CD',
#        'DT.DIS.MLAT.PS.CD', 'DT.DOD.MLAT.PS.CD', 'DT.INT.MLAT.PS.CD',
#        'DT.NFL.MLAT.PS.CD', 'DT.NTR.MLAT.PS.CD', 'DT.TDS.MLAT.PS.CD',
#        'DT.AMT.MLTC.PS.CD', 'DT.DIS.MLTC.PS.CD', 'DT.DOD.MLTC.PS.CD',
#        'DT.INT.MLTC.PS.CD', 'DT.NFL.MLTC.PS.CD', 'DT.NTR.MLTC.PS.CD',
#        'DT.TDS.MLTC.PS.CD', 'DT.AMT.OFFT.PS.CD', 'DT.DIS.OFFT.PS.CD',
#        'DT.DOD.OFFT.PS.CD', 'DT.INT.OFFT.PS.CD', 'DT.NFL.OFFT.PS.CD',
#        'DT.NTR.OFFT.PS.CD', 'DT.TDS.OFFT.PS.CD', 'DT.AMT.PROP.PS.CD',
#        'DT.DIS.PROP.PS.CD', 'DT.DOD.PROP.PS.CD', 'DT.INT.PROP.PS.CD',
#        'DT.NFL.PROP.PS.CD', 'DT.NTR.PROP.PS.CD', 'DT.TDS.PROP.PS.CD',
#        'DT.AMT.PRVT.PS.CD', 'DT.DIS.PRVT.PS.CD', 'DT.DOD.PRVT.PS.CD',
#        'DT.INT.PRVT.PS.CD', 'DT.NFL.PRVT.PS.CD', 'DT.NTR.PRVT.PS.CD',
#        'DT.TDS.PRVT.PS.CD', 'DT.DOD.RSDL.CD', 'DT.DOD.DSTC.ZS',
#        'BX.GRT.TECH.CD.DT', 'DT.TXR.DPPG.CD', 'DT.DOD.DECT.CD.CG',
#        'DT.TDS.DECT.EX.ZS', 'FI.RES.TOTL.DT.ZS', 'FI.RES.TOTL.CD',
#        'FI.RES.TOTL.MO', 'DT.UND.OFFT.CD', 'DT.UND.PRVT.CD',
#        'DT.UND.DPPG.CD', 'DT.DOD.DIMF.CD', 'DT.DOD.DSDR.CD'], dtype=object)

# %% [markdown]
# ## Q4) Totaling the amount of debt owed by the countries

# %%
df.groupby("country_name").agg({"debt": "sum"}).reset_index().head(15)
# Out:
#               country_name            debt
# 0              Afghanistan    965043287303
# 1                  Albania   2208876927555
# 2                  Algeria  22669445787378
# 3                   Angola  18047951503842
# 4                Argentina  80523169569240
# 5                  Armenia   2293963774440
# 6               Azerbaijan   4967898255773
# 7               Bangladesh  22140185236850
# 8                  Belarus   8564862470980
# 9                   Belize    592786273544
# 10                   Benin   1723572719067
# 11                  Bhutan    670892130049
# 12                 Bolivia   5704820240972
# 13  Bosnia and Herzegovina   3326984801167
# 14                Botswana   1557117009021

# %% [markdown]
# ## Q5) Country with the highest debt

# %%
# Group by country name and calculate total debt for each country

country_debt = df.groupby("country_name").agg({"debt": "sum"}).reset_index()

# Sort by debt in descending order and select the top row

highest_debt_country = country_debt.sort_values("debt", ascending=False).iloc[0]

print(highest_debt_country)
# Out:
# country_name              China
# debt            449304272541426
# Name: 24, dtype: object

# %% [markdown]
# ## Q6) Average amount of debt across indicators

# %%
df.head()
# Out:
#   country_name country_code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                       indicator_name indicator_code  debt
# 0  Average grace period on new external debt comm...    DT.GPA.DPPG   104
# 1  Average grace period on new external debt comm...    DT.GPA.OFFT   104
# 2  Average grace period on new external debt comm...    DT.GPA.PRVT     0
# 3  Average grant element on new external debt com...    DT.GRE.DPPG   392
# 4  Average grant element on new external debt com...    DT.GRE.OFFT   392

# %%
df.groupby("indicator_name").agg({"debt": "mean"}).reset_index().head(15)
# Out:
#                                        indicator_name          debt
# 0   Average grace period on new external debt comm...  2.842857e+02
# 1   Average grace period on new external debt comm...  2.810714e+02
# 2   Average grace period on new external debt comm...  1.173016e+02
# 3   Average grant element on new external debt com...  7.611270e+02
# 4   Average grant element on new external debt com...  9.763968e+02
# 5   Average grant element on new external debt com... -2.078968e+02
# 6   Average interest on new external debt commitme...  1.576111e+02
# 7   Average interest on new external debt commitme...  1.281905e+02
# 8   Average interest on new external debt commitme...  1.716587e+02
# 9   Average maturity on new external debt commitme...  9.682778e+02
# 10  Average maturity on new external debt commitme...  1.057873e+03
# 11  Average maturity on new external debt commitme...  2.713571e+02
# 12                   CB, bilateral (AMT, current US$)  2.290535e+08
# 13                   CB, bilateral (DIS, current US$)  5.204244e+08
# 14                   CB, bilateral (DOD, current US$)  4.665672e+09

# %% [markdown]
# ## Q7) The highest amount of principal repayments

# %%
# Select the highest repayment amount and the corresponding indicator name

df.loc[df["debt"].idxmax()]
# Out:
# country_name                  China
# country_code                    CHN
# indicator_name    GNI (current US$)
# indicator_code       NY.GNP.MKTP.CD
# debt                155843403932082
# Name: 13855, dtype: object

# %% [markdown]
# ## Q8) The most common debt indicator

# %%
# Group by indicator name and count the number of occurrences for each indicator code

common_indicator = df.groupby("indicator_name").agg({"indicator_code": "count"}).reset_index()

# Sort by count in descending order and select the top row

common_indicator.sort_values("indicator_code", ascending=False).iloc[0]
# Out:
# indicator_name    Average grace period on new external debt comm...
# indicator_code                                                  126
# Name: 0, dtype: object

# %% [markdown]
# ## Q9) Other viable debt issues and conclusion

# %%
# Group by country name and indicator code and select the maximum debt value

max_debt = df.groupby(["country_name", "indicator_code"]).agg({"debt": "max"}).reset_index()

# Sort by maximum debt in descending order and select the top 5 rows

max_debt.sort_values("debt", ascending=False).head(5)
# Out:
#       country_name  indicator_code             debt
# 14224        China  NY.GNP.MKTP.CD  155843403932082
# 58606   South Asia  NY.GNP.MKTP.CD   50213527341658
# 14221        China  FI.RES.TOTL.CD   46519850561521
# 9103        Brazil  NY.GNP.MKTP.CD   42128868879449
# 30725        India  NY.GNP.MKTP.CD   39270517390206
